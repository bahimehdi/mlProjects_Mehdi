# %% [markdown]
# # Projet 14: Juste Valeur de Voiture d'Occasion (Intermédiaire)
#
# ## Introduction
# Ce projet vise à estimer la juste valeur des voitures d'occasion.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Chargement des Données
# Nous allons charger le dataset `voitures_occasion.csv`.

# %%
try:
    df = pd.read_csv('../voitures_occasion.csv')
    print('Données chargées avec succès')
    display(df.head())
except FileNotFoundError:
    print('Fichier non trouvé')

# %% [markdown]
# ## Analyse Exploratoire
# Visualisons la distribution des prix.

# %%
if 'Price' in df.columns:
    sns.histplot(df['Price'])
    plt.title('Distribution des Prix')
    plt.show()

# %% [markdown]
# ## Modélisation
# L'objectif est de prédire le prix.

# %%
# Code de préparation des données et modélisation ici

# %% [markdown]
# ## Conclusion
# Synthèse des résultats obtenus.
